# %% [markdown]
# Notebook para testar o llm como fonte de detecção de idioma.

# %%
import requests
import json

# %%
MODEL_NAME = "gemma3:1b"  # ex: "llama3"

def detectar_idioma(pergunta: str) -> str:
    prompt = f"""
Detect the language of the following text.
Return ONLY the language name (in English).
Do not explain anything.
Do not answer the question.

Text: {pergunta}
"""

    payload = {
        "model": MODEL_NAME,
        "prompt": prompt,
        "stream": False
    }

    response = requests.post(
        "http://localhost:11434/api/generate",
        json=payload
    )

    result = response.json()
    return result["response"].strip()

# %%
pergunta = input("Digite sua pergunta: ")
idioma = detectar_idioma(pergunta)
print(idioma)
# Out:
# English
